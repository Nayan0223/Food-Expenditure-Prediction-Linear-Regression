# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('food.csv')
df
# Out:
#     food_exp  income  incomebc
# 0     115.22    3.69  1.305626
# 1     135.98    4.39  1.479329
# 2     119.34    4.75  1.558145
# 3     114.96    6.03  1.796747
# 4     187.05   12.47  2.523326
# 5     243.92   12.98  2.563410
# 6     267.43   14.20  2.653242
# 7     238.71   14.76  2.691921
# 8     295.94   15.32  2.729159
# 9     317.78   16.39  2.796671
# 10    216.00   17.35  2.853593
# 11    240.35   17.77  2.877512
# 12    386.57   17.93  2.886475
# 13    261.53   18.43  2.913980
# 14    249.34   18.55  2.920470
# 15    309.87   18.80  2.933857
# 16    345.89   18.81  2.934389
# 17    165.54   19.04  2.946542
# 18    196.98   19.22  2.955951
# 19    395.26   19.93  2.992226
# 20    406.34   20.13  3.002211
# 21    171.92   20.33  3.012098
# 22    303.23   20.37  3.014063
# 23    377.04   20.43  3.017004
# 24    194.35   21.45  3.065725
# 25    213.48   22.52  3.114404
# 26    293.87   22.55  3.115735
# 27    259.61   22.86  3.129389
# 28    323.71   24.20  3.186353
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   food_exp  40 non-null     float64
#  1   income    40 non-null     float64
#  2   incomebc  40 non-null     float64
# dtypes: float64(3)
# memory usage: 1.1 KB

# %%
df.describe()
# Out:
#          food_exp     income   incomebc
# count   40.000000  40.000000  40.000000
# mean   283.573500  19.604750   2.880925
# std    112.675181   6.847773   0.509032
# min    109.710000   3.690000   1.305626
# 25%    200.377500  17.110000   2.839362
# 50%    264.480000  20.030000   2.997219
# 75%    363.325000  24.397500   3.194481
# max    587.660000  33.400000   3.508556

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
plt.scatter(x =df.food_exp, y = df.income)
plt.title('Food_exp vs income')
plt.show()

# %%
X = df.drop("food_exp", axis = "columns")
y = df['incomebc']
print("shape of X = ", X.shape)
print("shape of y = ", y.shape)
# Out:
# shape of X =  (40, 2)
# shape of y =  (40,)

# %%
y
# Out:
# 0     1.305626
# 1     1.479329
# 2     1.558145
# 3     1.796747
# 4     2.523326
# 5     2.563410
# 6     2.653242
# 7     2.691921
# 8     2.729159
# 9     2.796671
# 10    2.853593
# 11    2.877512
# 12    2.886475
# 13    2.913980
# 14    2.920470
# 15    2.933857
# 16    2.934389
# 17    2.946542
# 18    2.955951
# 19    2.992226
# 20    3.002211
# 21    3.012098
# 22    3.014063
# 23    3.017004
# 24    3.065725
# 25    3.114404
# 26    3.115735
# 27    3.129389
# 28    3.186353
# 29    3.194173
# 30    3.195402
# 31    3.226844
# 32    3.238678
# 33    3.281287
# 34    3.284664
# 35    3.301009
# 36    3.301745
# 37    3.354106
# 38    3.380995
# 39    3.508556
# Name: incomebc, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2,random_state=51)
X_test
# Out:
#     income  incomebc
# 17   19.04  2.946542
# 15   18.80  2.933857
# 34   26.70  3.284664
# 11   17.77  2.877512
# 0     3.69  1.305626
# 22   20.37  3.014063
# 23   20.43  3.017004
# 18   19.22  2.955951

# %%
y_test.shape
# Out:
# (8,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1.70533832e-17, 1.00000000e+00])

# %%
lr.intercept_
# Out:
# 4.440892098500626e-16

# %%
m = 6.65
c = 26.80
y = m * 4 +c
y
# Out:
# 53.400000000000006

# %%
lr.predict(X_test)
# Out:
# array([2.94654203, 2.93385687, 3.28466357, 2.87751164, 1.30562646,
#        3.01406323, 3.01700441, 2.9559514 ])

# %%
y_pred  = lr.predict(X_test)
y_pred
# Out:
# array([2.94654203, 2.93385687, 3.28466357, 2.87751164, 1.30562646,
#        3.01406323, 3.01700441, 2.9559514 ])

# %%
df = pd.DataFrame(df, columns=["Food_exp_1", "Food_exp_2", "income", "predict income for food_exp"])

# %%
lr.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predict = lr.predict(X_test)[:1]

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_predict, color = "r")

# %%
print(y_test.shape, y_predict.shape)  # Should be (n,) not (n,1)
# Out:
# (8,) (8,)

# %%
sns.regplot(x=y_test,y=y_predict)
# Out:
# <Axes: xlabel='incomebc'>
